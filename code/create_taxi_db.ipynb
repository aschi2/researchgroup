# %% [markdown]
# We will be using pandas and sqlalchemy in order to read the taxi dataset from the <a href="http:\
# //www.nyc.gov/html/tlc/html/about/trip_record_data.shtml">nyc.gov</a>.
# Pandas is a package for R-like dataframes in python, which has great input-output (I/O).
# You can find documentation on pandas I/O <a href="http://pandas.pydata.org/pandas-docs/stable/io\
# .html">here</a>.
# First, let's import what we'll need.

# %%
from sqlalchemy import create_engine
import pandas as pd
from pandas import io

# %% [markdown]
# Let's start by reading some of the csv using iterators in read_csv.

# %%
csvfile = "https://storage.googleapis.com/tlc-trip-data/2015/yellow_tripdata_2015-01.csv"

# %%
yellow_df = pd.read_csv(csvfile, iterator=True, chunksize = 10000)

engine = create_engine('sqlite:///taxi.sqlite')

# %% [markdown]
# The yellow_df is actually a readtextfile object, because we said iterator=True.  This means that it is iterable (we use it in a for below) and not a dataframe.  We have to use the next to get the next 1000 entries in the csv which is then a dataframe.

# %%
tablecur = yellow_df.next()
tablecur.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111           1
# 1           3.30        -74.001648        40.724243           1
# 2           1.80        -73.963341        40.802788           1
# 3           0.50        -74.009087        40.713818           1
# 4           3.00        -73.971176        40.762428           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.974785         40.750618             1
# 1                  N         -73.994415         40.759109             1
# 2                  N         -73.951820         40.824413             2
# 3                  N         -74.004326         40.719986             2
# 4                  N         -74.004181         40.742653             2
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0         12.0    1.0      0.5        3.25           0.0
# 1         14.5    0.5      0.5        2.00           0.0
# 2          9.5    0.5      0.5        0.00           0.0
# 3          3.5    0.5      0.5        0.00           0.0
# 4         15.0    0.5      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.3         17.05
# 1                    0.3         17.80
# 2                    0.3         10.80
# 3                    0.3          4.80
# 4                    0.3         16.30

# %% [markdown]
# We initialize the sql table 'yellow' below with the first 1000 lines.  We check to make sure that this matches what we have above.

# %%
tablecur.to_sql('yellow',engine)

# %%
io.sql.read_sql_table('yellow',engine).head()
# Out:
#    index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0      0         2  2015-01-15 19:05:39   2015-01-15 19:23:42
# 1      1         1  2015-01-10 20:33:38   2015-01-10 20:53:28
# 2      2         1  2015-01-10 20:33:38   2015-01-10 20:43:41
# 3      3         1  2015-01-10 20:33:39   2015-01-10 20:35:31
# 4      4         1  2015-01-10 20:33:39   2015-01-10 20:52:58
#
#    passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                1           1.59        -73.993896        40.750111
# 1                1           3.30        -74.001648        40.724243
# 2                1           1.80        -73.963341        40.802788
# 3                1           0.50        -74.009087        40.713818
# 4                1           3.00        -73.971176        40.762428
#
#    RateCodeID store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# 0           1                  N         -73.974785         40.750618
# 1           1                  N         -73.994415         40.759109
# 2           1                  N         -73.951820         40.824413
# 3           1                  N         -74.004326         40.719986
# 4           1                  N         -74.004181         40.742653
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         12.0    1.0      0.5        3.25           0.0
# 1             1         14.5    0.5      0.5        2.00           0.0
# 2             2          9.5    0.5      0.5        0.00           0.0
# 3             2          3.5    0.5      0.5        0.00           0.0
# 4             2         15.0    0.5      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.3         17.05
# 1                    0.3         17.80
# 2                    0.3         10.80
# 3                    0.3          4.80
# 4                    0.3         16.30

# %% [markdown]
# Next we have to iterate over the remaining csv file and insert it into the sql table.  To insert we have to use the if_exists='append' arg.

# %%
for tablecur in yellow_df:
    tablecur.to_sql('yellow',engine,if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-50-94a23d0d2ffe> in <module>()
# ----> 1 for tablecur in yellow_df:
#       2     tablecur.to_sql('yellow',engine,if_exists='append')
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/common.pyc in <lambda>(self)
#     102
#     103 if not compat.PY3:
# --> 104     BaseIterator.next = lambda self: self.__next__()
#     105
#     106
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in __next__(self)
#     793
#     794     def __next__(self):
# --> 795         return self.get_chunk()
#     796
#     797     def _make_engine(self, engine='c'):
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in get_chunk(self, size)
#     834         if size is None:
#     835             size = self.chunksize
# --> 836         return self.read(nrows=size)
#     837
#     838
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in read(self, nrows)
#     813                 raise ValueError('skip_footer not supported for iteration')
#     814
# --> 815         ret = self._engine.read(nrows)
#     816
#     817         if self.options.get('as_recarray'):
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in read(self, nrows)
#    1312     def read(self, nrows=None):
#    1313         try:
# -> 1314             data = self._reader.read(nrows)
#    1315         except StopIteration:
#    1316             if self._first_chunk:
#
# pandas/parser.pyx in pandas.parser.TextReader.read (pandas/parser.c:8748)()
#
# pandas/parser.pyx in pandas.parser.TextReader._read_low_memory (pandas/parser.c:9208)()
#
# pandas/parser.pyx in pandas.parser.TextReader._read_rows (pandas/parser.c:9731)()
#
# pandas/parser.pyx in pandas.parser.TextReader._tokenize_rows (pandas/parser.c:9602)()
#
# pandas/parser.pyx in pandas.parser.raise_parser_error (pandas/parser.c:23325)()
#
# CParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %% [markdown]
# Now, the first csv file is in the database in the local directory under taxi.sqlite.
#
# TODO: append all of the csv files in this way by iterating over all of the urls of the CSVs (there is probably a pattern) and appending to the yellow table with the above line.  This will make a LARGE sqlite document.

# %%
io.sql.read_sql_query('SELECT * FROM yellow WHERE fare_amount=9.5',engine).head()
# Out:
#    index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0      2         1  2015-01-10 20:33:38   2015-01-10 20:43:41
# 1     42         2  2015-01-25 00:13:06   2015-01-25 00:23:26
# 2     55         2  2015-01-25 00:13:09   2015-01-25 00:22:51
# 3    135         2  2015-01-07 14:58:07   2015-01-07 15:10:17
# 4    206         1  2015-01-26 13:04:18   2015-01-26 13:15:21
#
#    passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                1           1.80        -73.963341        40.802788
# 1                1           2.01        -73.948685        40.782360
# 2                2           2.22        -73.992531        40.724461
# 3                2           1.58        -73.981956        40.769260
# 4                1           2.10        -73.944443        40.741562
#
#    RateCodeID store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# 0           1                  N         -73.951820         40.824413
# 1           1                  N         -73.957085         40.801991
# 2           1                  N         -74.010895         40.703266
# 3           1                  N         -73.973465         40.789776
# 4           1                  N         -73.931107         40.764935
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             2          9.5    0.5      0.5        0.00           0.0
# 1             1          9.5    0.5      0.5        2.16           0.0
# 2             1          9.5    0.5      0.5        2.70           0.0
# 3             1          9.5    0.0      0.5        1.00           0.0
# 4             1          9.5    0.0      0.5        1.00           0.0
#
#    improvement_surcharge  total_amount
# 0                    0.3         10.80
# 1                    0.3         12.96
# 2                    0.3         13.50
# 3                    0.3         11.30
# 4                    0.3         11.30

# %%
io.sql.read_sql_query("SELECT * FROM yellow WHERE DATE(tpep_pickup_datetime) = '2015-01-15'",engine).head()
# Out:
#    index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0      0         2  2015-01-15 19:05:39   2015-01-15 19:23:42
# 1     15         2  2015-01-15 19:05:39   2015-01-15 19:32:00
# 2     16         2  2015-01-15 19:05:40   2015-01-15 19:21:00
# 3     17         2  2015-01-15 19:05:40   2015-01-15 19:28:18
# 4     18         2  2015-01-15 19:05:41   2015-01-15 19:20:36
#
#    passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 0                1           1.59        -73.993896        40.750111
# 1                1           2.38        -73.976425        40.739811
# 2                5           2.83        -73.968704        40.754246
# 3                5           8.33        -73.863060        40.769581
# 4                1           2.37        -73.945541        40.779423
#
#    RateCodeID store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# 0           1                  N         -73.974785         40.750618
# 1           1                  N         -73.983978         40.757889
# 2           1                  N         -73.955124         40.786858
# 3           1                  N         -73.952713         40.785782
# 4           1                  N         -73.980850         40.786083
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         12.0    1.0      0.5        3.25          0.00
# 1             1         16.5    1.0      0.5        4.38          0.00
# 2             2         12.5    1.0      0.5        0.00          0.00
# 3             1         26.0    1.0      0.5        8.08          5.33
# 4             1         11.5    1.0      0.5        0.00          0.00
#
#    improvement_surcharge  total_amount
# 0                    0.3         17.05
# 1                    0.3         22.68
# 2                    0.3         14.30
# 3                    0.3         41.21
# 4                    0.3         13.30
